# %% [markdown]
# <a href="https://colab.research.google.com/github/mayankmisra1988/webscript/blob/main/Amazon_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

def get_title(soup):
  try:
    product_title=single_page_soup.find('span',attrs=({"id":"productTitle"})).text.strip()
  except:
    product_title=""
  return product_title

def get_size(soup):
  try:
    lst=[]
    for product_size in single_page_soup.find('select',attrs=({'name':'dropdown_selected_size_name'})):
      for size in product_size.stripped_strings:
        lst.append(size)
      # print(lst[1:])
  except:
    product_size=""
  return lst[1:]

def get_img(soup):
  try:
    div=single_page_soup.find('div',attrs=({'class':'imgTagWrapper'}))
    imges=div.img.get('src')
    lst_img=[]
    for pic in imges:
      for img in pic:
        lst_img.append(img)
    return ''.join(lst_img)

  except:
    product_size=""

# print(get_img(single_page_soup))



HEADERS=({"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36(KHTML,like Gecko)Chrome/126.0.0.0 Safari/537.36","Accept-Language":"en-US,en;q=0.5"})
# ,"Accept-Language":"en-US,en;q=0.5"
URL="https://www.amazon.in/s?k=women+kurta&i=apparel&rh=n%3A1571271031&dc&ds=v1%3AoUIjJkiILG7RdD8aIhPheYTgtg8ThpyVWRDDo4sedVk&qid=1722317457&rnid=91049095031&ref=sr_nr_p_123_1"

page=requests.get(URL,headers=HEADERS)
# page

soup=BeautifulSoup(page.content,'html.parser')
links=soup.find_all('a',attrs={'class':'a-link-normal s-no-outline'})
# links
link_list=[]
for link in links:
  link_list.append("https://www.amazon.in/"+link.get('href'))

dict1={"Title":[],"size":[],"img":[]}

for link in link_list:
  product_page=requests.get(link,headers=HEADERS)
  single_page_soup=BeautifulSoup(product_page.content,'html.parser')
  dict1["Title"].append(get_title(single_page_soup))
  dict1["size"].append(get_size(single_page_soup))
  dict1['img'].append(get_img(single_page_soup))

dict1



# link="https://www.amazon.in/"+links[0].get('href')
# # link
# product_page=requests.get(link,headers=HEADERS)
# single_page_soup=BeautifulSoup(product_page.content,'html.parser')
# product_title=single_page_soup.find('span',attrs=({"id":"productTitle"})).text.strip()
# product_title

#####################( find the size of items) ###################################
# lst=[]
# for product_size in single_page_soup.find('select',attrs=({'name':'dropdown_selected_size_name'})):
#   for size in product_size.stripped_strings:
#     lst.append(size)
# print(lst[1:])


#####################( find the img tag) ###################################


# div=single_page_soup.find('div',attrs=({'class':'imgTagWrapper'}))

# for pic in div.img.get('src'):
#   for img in pic:
#     ''.join(img)

# def get_img(soup):
#   div=single_page_soup.find('div',attrs=({'class':'imgTagWrapper'}))
#   lst_img=[]
#   for pic in div.img.get('src'):
#     for img in pic:
#       lst_img.append(img)
#   return ''.join(lst_img)
# print(get_img(single_page_soup))
# Out:
# {'Title': [],
#  'size': [],
#  'img': ['https://m.media-amazon.com/images/I/31a0fI5EhuL._SY445_SX342_.jpg',
#   'https://m.media-amazon.com/images/I/313qbi35oCL._SX342_SY445_.jpg',
#   'https://m.media-amazon.com/images/I/41B-ebCdKOL._SY445_SX342_.jpg',
#   'https://m.media-amazon.com/images/I/31-ZbOC-aML._SY445_SX342_.jpg',
#   'https://m.media-amazon.com/images/I/41JnkRm0t5L._SX342_SY445_.jpg',
#   'https://m.media-amazon.com/images/I/4128JXli0YL._SY445_SX342_.jpg',
#   'https://m.media-amazon.com/images/I/418qDRN94TL._SX342_SY445_.jpg',
#   None,
#   None,
#   'https://m.media-amazon.com/images/I/41b7RzjnB0L._SY445_SX342_.jpg',
#   'https://m.media-amazon.com/images/I/31XG36Uu9HL._SY445_SX342_.jpg',
#   'https://m.media-amazon.com/images/I/31dDpvOK55L._SY445_SX342_.jpg',
#   'https://m.media-amazon.com/images/I/31HoTrVVk6L._SY445_SX342_.jpg',
#   'https://m.media-amazon.com/images/I/31hKRxo5YdL._SY445_SX342_.jpg',
# ...
